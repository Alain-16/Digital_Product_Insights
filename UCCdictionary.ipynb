# %%
import re
import pandas as pd

# %%
def extract_digital_ucc(filepath):
    
    digital_keywords =[
        "computer","software","internet","hardware","network","online","video games","streaming","downloading",
        "digital","applications","satellite television","cellular phone","portable","accessories","television",
        "telephone","ebook","ovens","speakers","Photographic equipment"
    ]

    digital_ucc =[]

    try:
        with open(filepath,'r') as file:
            for line in file:
                match = re.search(r'^\d+\s+\d+\s+(.*?)\s{2,}(\d{6})\s+I', line)

                if match:
                    description = match.group(1).strip()
                    ucc_code = match.group(2)
                
                    if any(key in description.lower() for key in digital_keywords):
                        digital_ucc.append({
                            "UCC": ucc_code,
                            "Description": description
                        })
    except FileNotFoundError:
        return "file not found"
    
    return digital_ucc

# %%
results = extract_digital_ucc("/home/alain/Documents/Data science notes/stubs/CE-HG-Inter-2023.txt")

for items in results:
    print(f"UCC: {items['UCC']} | {items['Description']}")
# Out:
# UCC: 270102 | Cellular phone service
# UCC: 270106 | Residential telephone including VOIP
# UCC: 690113 | Repair of computer systems for nonbusiness use
# UCC: 690114 | Computer information services (internet)
# UCC: 690310 | Installation of computers
# UCC: 300311 | Cooking stoves and ovens (renter)
# UCC: 300312 | Cooking stoves and ovens (owned home)
# UCC: 300321 | Microwave ovens (renter)
# UCC: 300322 | Microwave ovens (owned home)
# UCC: 300331 | Portable dishwashers (renter)
# UCC: 300332 | Portable dishwashers (owned home)
# UCC: 320522 | Portable heating and cooling equipment
# UCC: 320232 | Telephones and accessories
# UCC: 690111 | Computers and computer hardware for nonbusiness use
# UCC: 690117 | Portable memory
# UCC: 690119 | Computer software
# UCC: 690120 | Computer accessories
# UCC: 690116 | Internet services away from home
# UCC: 480100 | Vehicle parts, accessories, fluid excluding tires
# UCC: 480213 | Parts, equipment, and accessories (through Q20231)
# UCC: 490501 | Vehicle accessories including labor (through Q20231)
# UCC: 310316 | Stereos, radios, speakers, and sound components
# UCC: 310140 | Televisions
# UCC: 270310 | Cable and satellite television services
# UCC: 620930 | Online gaming services
# UCC: 310231 | Video game software
# UCC: 310232 | Video game hardware and accessories
# UCC: 310400 | Applications, games, and ringtones for handheld devices
# UCC: 340610 | Repair of televisions, radio, and sound equipment
# UCC: 340902 | Rental of televisions
# UCC: 310314 | Personal digital audio players
# UCC: 310350 | Streaming and downloading audio
# UCC: 610130 | Musical instruments and accessories
# UCC: 310243 | Rental, streaming, and downloading videos
# UCC: 620917 | Rental of video hardware/accessories
# UCC: 620918 | Rental of video software
# UCC: 310333 | Accessories and other sound equipment
# UCC: 690320 | Installation of televisions
# UCC: 690330 | Installation of satellite television equipment
# UCC: 590230 | Books, digital books, or book subscriptions
# UCC: 690118 | Digital book readers
# UCC: 300311 | Cooking stoves and ovens (renter)
# UCC: 300312 | Cooking stoves and ovens (owned home)
# UCC: 300321 | Microwave ovens (renter)
# UCC: 300322 | Microwave ovens (owned home)
# UCC: 300331 | Portable dishwashers (renter)
# UCC: 300332 | Portable dishwashers (owned home)
# UCC: 320522 | Portable heating and cooling equipment
# UCC: 320232 | Telephones and accessories
# UCC: 690111 | Computers and computer hardware for nonbusiness use
# UCC: 690117 | Portable memory
# UCC: 690119 | Computer software
# UCC: 690120 | Computer accessories
# UCC: 690115 | Personal digital assistants
# UCC: 690116 | Internet services away from home
# UCC: 690210 | Telephone answering devices
# UCC: 270106 | Residential telephone including VOIP
# UCC: 690114 | Computer information services (internet)
# UCC: 690310 | Installation of computers
# UCC: 620930 | Online gaming services
# UCC: 270310 | Cable and satellite television services
# UCC: 310140 | Televisions
# UCC: 310231 | Video game software
# UCC: 310232 | Video game hardware and accessories
# UCC: 620917 | Rental of video hardware/accessories
# UCC: 620918 | Rental of video software
# UCC: 310243 | Rental, streaming, and downloading videos
# UCC: 310400 | Applications, games, and ringtones for handheld devices
# UCC: 310316 | Stereos, radios, speakers, and sound components
# UCC: 310314 | Personal digital audio players
# UCC: 610130 | Musical instruments and accessories
# UCC: 310333 | Accessories and other sound equipment
# UCC: 310350 | Streaming and downloading audio
